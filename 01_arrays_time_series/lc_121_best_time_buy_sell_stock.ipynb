# %% [markdown]
# # LeetCode #121 — Best Time to Buy and Sell Stock
#
# **Pattern:** Single-pass optimization (min-so-far)
# **Category:** Arrays / Time Series
#
# ## Problem Overview
# Given a time series of asset prices, determine the maximum achievable return
# from a single buy followed by a single sell.
#
# ## Financial Interpretation
# This problem mirrors a single-asset return optimization problem under perfect
# foresight and highlights drawdown behavior and timing intuition.
#
# ## Quant & Risk Relevance
# - Maximum return over a horizon
# - Drawdown sensitivity
# - Entry/exit timing
# - P&L intuition
